# %%
import torch
import math
import diffusion
import numpy as np

# %%
ode_samples = np.load("results/ode_samples_true.npz")
x, states = ode_samples.values()

# %%
(x ** 2).sum(axis=(1, 2, 3))
# Out:
# array([3.0684971e+14, 3.9523732e+14, 3.6694959e+14, 4.1064870e+14,
#        4.1785958e+14, 3.8380781e+14, 4.3413130e+14, 3.2415588e+14,
#        4.1663612e+14, 5.1179075e+14, 4.3213750e+14, 3.8326043e+14,
#        4.8200801e+14, 4.1504400e+14, 4.0961533e+14, 4.0510950e+14,
#        3.9214659e+14, 4.4867993e+14, 3.4917396e+14, 4.9953537e+14,
#        5.2544935e+14, 4.3999937e+14, 4.2544137e+14, 4.4150710e+14,
#        4.4706640e+14, 4.2891023e+14, 4.8299296e+14, 3.2401854e+14,
#        4.1492350e+14, 5.3979682e+14, 4.2946656e+14, 4.7196728e+14,
#        4.1454793e+14, 4.1904506e+14, 4.6830025e+14, 4.4891998e+14],
#       dtype=float32)

# %%
(states ** 2).sum(axis=(2, 3, 4)).mean(0) ** 0.5
# Out:
# array([1.37471900e+07, 1.08017800e+07, 9.04333700e+06, 7.83736950e+06,
#        6.94427850e+06, 6.24948550e+06, 5.69014350e+06, 5.22826700e+06,
#        4.83929900e+06, 4.50655850e+06, 4.21823900e+06, 3.96570125e+06,
#        3.74247175e+06, 3.54358000e+06, 3.36515450e+06, 3.20411275e+06,
#        3.05797375e+06, 2.92471575e+06, 2.80267150e+06, 2.69045775e+06,
#        2.58691000e+06, 2.49104275e+06, 2.40201775e+06, 2.31911575e+06,
#        2.24171475e+06, 2.16927675e+06, 2.10133125e+06, 2.03746600e+06,
#        1.97731838e+06, 1.92056825e+06, 1.86693112e+06, 1.81615338e+06,
#        1.76800862e+06, 1.72229400e+06, 1.67882750e+06, 1.63744400e+06,
#        1.59799488e+06, 1.56034538e+06, 1.52437300e+06, 1.48996650e+06,
#        1.45702312e+06, 1.42545062e+06, 1.39516312e+06, 1.36608225e+06,
#        1.33813600e+06, 1.31125812e+06, 1.28538688e+06, 1.26046575e+06,
#        1.23644225e+06, 1.21326762e+06, 1.19089662e+06, 1.16928738e+06,
# ...
