# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ode_samples = np.load("results/ode_samples.npz")
ode_samples_from_50 = np.load("results/small_steps_from_50_ode_samples.npz")

# %%
plt.plot(ode_samples_from_50["ll"].mean(axis=1)[::-1])
plt.show()

# %%
ode_samples["ll"].shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ode_samples["ll"].shape
#
# File ~/.local/lib/python310-conda-cuda-torch21/site-packages/numpy/lib/npyio.py:263, in NpzFile.__getitem__(self, key)
#     261         return self.zip.read(key)
#     262 else:
# --> 263     raise KeyError(f"{key} is not a file in the archive")
#
# KeyError: 'll is not a file in the archive'

# %%
ode_samples_from_50["ll"].shape
# Out:
# (501, 36)

# %%
plt.plot(ode_samples["ll"].mean(1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot(ode_samples["ll"].mean(1))
#
# File ~/.local/lib/python310-conda-cuda-torch21/site-packages/numpy/lib/npyio.py:263, in NpzFile.__getitem__(self, key)
#     261         return self.zip.read(key)
#     262 else:
# --> 263     raise KeyError(f"{key} is not a file in the archive")
#
# KeyError: 'll is not a file in the archive'

# %%
plt.imshow(ode_samples["x"][0][0])
